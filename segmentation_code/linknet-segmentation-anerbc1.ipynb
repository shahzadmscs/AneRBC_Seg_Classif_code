# %%
# import os
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras.losses import binary_crossentropy
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
# Out:
# D1027 06:39:03.926014149      15 config.cc:119]                        gRPC EXPERIMENT tcp_frame_size_tuning               OFF (default:OFF)
# D1027 06:39:03.926043320      15 config.cc:119]                        gRPC EXPERIMENT tcp_rcv_lowat                       OFF (default:OFF)
# D1027 06:39:03.926047201      15 config.cc:119]                        gRPC EXPERIMENT peer_state_based_framing            OFF (default:OFF)
# D1027 06:39:03.926050592      15 config.cc:119]                        gRPC EXPERIMENT flow_control_fixes                  ON  (default:ON)
# D1027 06:39:03.926053266      15 config.cc:119]                        gRPC EXPERIMENT memory_pressure_controller          OFF (default:OFF)
# D1027 06:39:03.926056296      15 config.cc:119]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size OFF (default:OFF)
# D1027 06:39:03.926058924      15 config.cc:119]                        gRPC EXPERIMENT new_hpack_huffman_decoder           ON  (default:ON)
# D1027 06:39:03.926061621      15 config.cc:119]                        gRPC EXPERIMENT event_engine_client                 OFF (default:OFF)
# D1027 06:39:03.926064389      15 config.cc:119]                        gRPC EXPERIMENT monitoring_experiment               ON  (default:ON)
# D1027 06:39:03.926067045      15 config.cc:119]                        gRPC EXPERIMENT promise_based_client_call           OFF (default:OFF)
# D1027 06:39:03.926069719      15 config.cc:119]                        gRPC EXPERIMENT free_large_allocator                OFF (default:OFF)
# D1027 06:39:03.926072353      15 config.cc:119]                        gRPC EXPERIMENT promise_based_server_call           OFF (default:OFF)
# D1027 06:39:03.926075014      15 config.cc:119]                        gRPC EXPERIMENT transport_supplies_client_latency   OFF (default:OFF)
# D1027 06:39:03.926077538      15 config.cc:119]                        gRPC EXPERIMENT event_engine_listener               OFF (default:OFF)
# I1027 06:39:03.926349990      15 ev_epoll1_linux.cc:122]               grpc epoll fd: 61
# D1027 06:39:03.926364470      15 ev_posix.cc:144]                      Using polling engine: epoll1
# D1027 06:39:03.926435415      15 dns_resolver_ares.cc:822]             Using ares dns resolver
# D1027 06:39:03.935571212      15 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D1027 06:39:03.935587464      15 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D1027 06:39:03.935591494      15 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D1027 06:39:03.935594790      15 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D1027 06:39:03.935598298      15 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D1027 06:39:03.935601600      15 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin_experimental"
# D1027 06:39:03.935610212      15 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D1027 06:39:03.935631724      15 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D1027 06:39:03.935664473      15 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D1027 06:39:03.935681944      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D1027 06:39:03.935685447      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D1027 06:39:03.935689027      15 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D1027 06:39:03.935697540      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_resolver_experimental"
# D1027 06:39:03.935701134      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D1027 06:39:03.935704490      15 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D1027 06:39:03.935709204      15 certificate_provider_registry.cc:35]  registering certificate provider factory for "file_watcher"
# I1027 06:39:03.939769940      15 socket_utils_common_posix.cc:408]     Disabling AF_INET6 sockets because ::1 is not available.
# I1027 06:39:03.955110801     303 socket_utils_common_posix.cc:337]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# E1027 06:39:03.960751771     303 oauth2_credentials.cc:236]            oauth_fetch: UNKNOWN:C-ares status is not ARES_SUCCESS qtype=A name=metadata.google.internal. is_balancer=0: Domain name not found {created_time:"2023-10-27T06:39:03.960736474+00:00", grpc_status:2}

# %%
class ImageDataLoader(Sequence):
    def __init__(self, input_dir, target_dir, filenames, batch_size, img_size=(512, 512)):
        self.input_dir = input_dir
        self.target_dir = target_dir
        self.filenames = filenames
        self.batch_size = batch_size
        self.img_size = img_size
    
    def __len__(self):
        return int(np.ceil(len(self.filenames) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.filenames[idx * self.batch_size: (idx + 1) * self.batch_size]
        x = []
        y = []
        for file_name in batch_x:
            input_img = cv2.imread(os.path.join(self.input_dir, file_name))
            input_img = cv2.resize(input_img, self.img_size) / 255.0
            
            target_img = cv2.imread(os.path.join(self.target_dir, file_name), cv2.IMREAD_GRAYSCALE)
            target_img = cv2.resize(target_img, self.img_size) / 255.0
            
            unique_values = np.unique(target_img)
            if not np.array_equal(unique_values, [0, 1]):
                _, target_img = cv2.threshold(target_img, 0.5, 1, cv2.THRESH_BINARY)
            
            target_img = np.expand_dims(target_img, axis=-1)
            
            x.append(input_img)
            y.append(target_img)
        
        return np.array(x), np.array(y)

# %%
# Custom metrics
def pixel_accuracy(y_true, y_pred):
    y_pred = K.round(y_pred)
    correct_pixels = K.sum(K.equal(y_true, y_pred))
    total_pixels = K.prod(K.shape(y_true))
    return correct_pixels / total_pixels

def iou(y_true, y_pred):
    y_pred = K.round(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return intersection / union

def dice_coef(y_true, y_pred):
    y_pred = K.round(y_pred)
    intersection = K.sum(y_true * y_pred)
    return (2. * intersection) / (K.sum(y_true) + K.sum(y_pred))

def specificity(y_true, y_pred):
    y_pred = K.round(y_pred)
    true_negatives = K.sum((1 - y_true) * (1 - y_pred))
    possible_negatives = K.sum(1 - y_true)
    return true_negatives / possible_negatives

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# Combined loss
def combined_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
from tensorflow.keras.layers import Conv2DTranspose

# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# instantiating the model in the strategy scope creates the model on the TPU
with tpu_strategy.scope():
    # LinkNet model
    def linknet_model(input_shape):
        inputs = Input(input_shape)

        # Encoder
        c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
        p1 = MaxPooling2D((2, 2))(c1)

        c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
        p2 = MaxPooling2D((2, 2))(c2)

        c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
        p3 = MaxPooling2D((2, 2))(c3)

        # Decoder
        u3 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(p3)
        d3 = Conv2D(128, (3, 3), activation='relu', padding='same')(u3)

        u2 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(d3)
        u2 = Concatenate()([u2, c2])
        d2 = Conv2D(128, (3, 3), activation='relu', padding='same')(u2)

        u1 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(d2)
        u1 = Concatenate()([u1, c1])
        d1 = Conv2D(64, (3, 3), activation='relu', padding='same')(u1)

        outputs = Conv2D(1, (1, 1), activation='sigmoid')(d1)

        return Model(inputs, outputs)
    
    model = linknet_model((512, 512, 3))
    model.compile(optimizer='adam', loss=combined_loss, 
                metrics=['accuracy', dice_coef, iou, Precision(), Recall(), specificity])

    model.summary()
# Out:
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# WARNING:tensorflow:TPU system local has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: local
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 64  1792        ['input_2[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 256, 256, 64  0          ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d_3[0][0]']
#                                 8)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 12  0          ['conv2d_8[0][0]']
#                                 8)
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_4[0][0]']
#                                 6)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 256)  0          ['conv2d_9[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 12  131200     ['max_pooling2d_5[0][0]']
#  spose)                         8)
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_transpose_3[0][0]']
#                                 8)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 256, 256, 12  65664      ['conv2d_10[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_4[0][0]',
#                                 6)                                'conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 512, 512, 64  32832      ['conv2d_11[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_5[0][0]',
#                                 8)                                'conv2d_7[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 512, 512, 1)  65          ['conv2d_12[0][0]']
#
# ==================================================================================================
# Total params: 1,116,993
# Trainable params: 1,116,993
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# from tensorflow.keras.layers import Conv2DTranspose

# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# # instantiate a distribution strategy
# # tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
# tpu_strategy = tf.distribute.TPUStrategy(tpu)
# # instantiating the model in the strategy scope creates the model on the TPU
# with tpu_strategy.scope():
#     # U-Net model
#     def unet_model(input_shape):
#         inputs = Input(input_shape)
#         c1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
#         p1 = MaxPooling2D((2, 2))(c1)
#         c2 = Conv2D(64, (3, 3), activation='relu', padding='same')(p1)
#         p2 = MaxPooling2D((2, 2))(c2)
#         c3 = Conv2D(128, (3, 3), activation='relu', padding='same')(p2)

#         # Use Conv2DTranspose for upsampling
#         u2 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c3)
#         u2 = Concatenate()([u2, c2])
#         c4 = Conv2D(64, (3, 3), activation='relu', padding='same')(u2)

#         # Use Conv2DTranspose for upsampling
#         u1 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c4)
#         u1 = Concatenate()([u1, c1])
#         outputs = Conv2D(1, (1, 1), activation='sigmoid')(u1)

#         return Model(inputs, outputs)
#     model = unet_model((300, 300, 3))
#     model.compile(optimizer='adam', loss=combined_loss, 
#               metrics=['accuracy', dice_coef, iou, Precision(), Recall(), specificity])

#     model.summary()

# %%
# Create a new instance of ImageDataLoader
import os
input_dir = '/kaggle/input/anemic-rbc-dataset/Anemic_RBC_dataset/AneRBC-II/Original_images/healthy'
target_dir= '/kaggle/input/anemic-rbc-dataset/Anemic_RBC_dataset/AneRBC-II/Binary_segmented/healthy'


all_image_filenames = os.listdir(input_dir)
train_filenames, val_filenames = train_test_split(all_image_filenames, test_size=0.2, random_state=42)

# %%
import os
import shutil

# Define source and destination directories
src_dir_original = "/kaggle/input/anemic-rbc-dataset/Anemic_RBC_dataset/AneRBC-II/Original_images/healthy/"
dest_dir_original = "/kaggle/working/Original_Images_healthy/"

src_dir_segmented = "/kaggle/input/anemic-rbc-dataset/Anemic_RBC_dataset/AneRBC-II/Binary_segmented/healthy/"
dest_dir_segmented = "/kaggle/working/Binary_Segmented_healthy/"

# Create destination directories if they don't exist
os.makedirs(dest_dir_original, exist_ok=True)
os.makedirs(dest_dir_segmented, exist_ok=True)

# Copy images to writable directories
for file_name in os.listdir(src_dir_original):
    shutil.copy(os.path.join(src_dir_original, file_name), dest_dir_original)

for file_name in os.listdir(src_dir_segmented):
    shutil.copy(os.path.join(src_dir_segmented, file_name), dest_dir_segmented)

# Apply mogrify command on copied images
# !mogrify -strip {dest_dir_original}*.png
# !mogrify -strip {dest_dir_segmented}*.png

# %%
# Create a new instance of ImageDataLoader
input_dir = '/kaggle/working/Original_Images_healthy/'
target_dir= '/kaggle/working/Binary_Segmented_healthy/'


all_image_filenames = os.listdir(input_dir)
train_filenames, val_filenames = train_test_split(all_image_filenames, test_size=0.2, random_state=42)

# %%
batch_size = 64

train_data_loader = ImageDataLoader(input_dir, target_dir, train_filenames, batch_size)
val_data_loader = ImageDataLoader(input_dir, target_dir, val_filenames, batch_size)

history = model.fit(train_data_loader, validation_data=val_data_loader, epochs=200)
# Out:
# Epoch 1/200
# 2023-10-27 06:52:07.976253: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Add_42/ReadVariableOp.
# 2023-10-27 06:52:08.186154: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Add_42/ReadVariableOp.
# 75/75 [==============================] - ETA: 0s - loss: 0.6112 - accuracy: 0.7820 - dice_coef: 0.8402 - iou: 0.7306 - precision_1: 0.7614 - recall_1: 0.9281 - specificity: 0.5635
# 2023-10-27 06:56:31.155732: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Add_2/ReadVariableOp.
# 2023-10-27 06:56:31.320340: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Add_2/ReadVariableOp.
# 75/75 [==============================] - 343s 4s/step - loss: 0.6112 - accuracy: 0.7820 - dice_coef: 0.8402 - iou: 0.7306 - precision_1: 0.7614 - recall_1: 0.9281 - specificity: 0.5635 - val_loss: 0.3816 - val_accuracy: 0.8836 - val_dice_coef: 0.9072 - val_iou: 0.8317 - val_precision_1: 0.8675 - val_recall_1: 0.9533 - val_specificity: 0.7805
# Epoch 2/200
# 75/75 [==============================] - 198s 3s/step - loss: 0.3629 - accuracy: 0.8930 - dice_coef: 0.9119 - iou: 0.8399 - precision_1: 0.8929 - recall_1: 0.9340 - specificity: 0.8360 - val_loss: 0.3280 - val_accuracy: 0.9015 - val_dice_coef: 0.9204 - val_iou: 0.8540 - val_precision_1: 0.8889 - val_recall_1: 0.9568 - val_specificity: 0.8210
# Epoch 3/200
# 75/75 [==============================] - 197s 3s/step - loss: 0.3081 - accuracy: 0.9109 - dice_coef: 0.9260 - iou: 0.8639 - precision_1: 0.9117 - recall_1: 0.9430 - specificity: 0.8675 - val_loss: 0.3560 - val_accuracy: 0.9016 - val_dice_coef: 0.9195 - val_iou: 0.8522 - val_precision_1: 0.9004 - val_recall_1: 0.9415 - val_specificity: 0.8448
# Epoch 4/200
# 75/75 [==============================] - 211s 3s/step - loss: 0.3383 - accuracy: 0.9025 - dice_coef: 0.9199 - iou: 0.8536 - precision_1: 0.9004 - recall_1: 0.9419 - specificity: 0.8477 - val_loss: 0.2648 - val_accuracy: 0.9247 - val_dice_coef: 0.9371 - val_iou: 0.8829 - val_precision_1: 0.9334 - val_recall_1: 0.9428 - val_specificity: 0.9020
# Epoch 5/200
# 75/75 [==============================] - 201s 3s/step - loss: 0.2702 - accuracy: 0.9238 - dice_coef: 0.9364 - iou: 0.8821 - precision_1: 0.9244 - recall_1: 0.9509 - specificity: 0.8882 - val_loss: 0.2451 - val_accuracy: 0.9306 - val_dice_coef: 0.9432 - val_iou: 0.8938 - val_precision_1: 0.9201 - val_recall_1: 0.9695 - val_specificity: 0.8761
# Epoch 6/200
# 75/75 [==============================] - 197s 3s/step - loss: 0.2621 - accuracy: 0.9263 - dice_coef: 0.9383 - iou: 0.8855 - precision_1: 0.9278 - recall_1: 0.9513 - specificity: 0.8939 - val_loss: 0.2641 - val_accuracy: 0.9227 - val_dice_coef: 0.9371 - val_iou: 0.8831 - val_precision_1: 0.9100 - val_recall_1: 0.9679 - val_specificity: 0.8585
# Epoch 7/200
# 75/75 [==============================] - 209s 3s/step - loss: 0.2525 - accuracy: 0.9293 - dice_coef: 0.9408 - iou: 0.8898 - precision_1: 0.9314 - recall_1: 0.9526 - specificity: 0.8997 - val_loss: 0.2508 - val_accuracy: 0.9285 - val_dice_coef: 0.9400 - val_iou: 0.8880 - val_precision_1: 0.9404 - val_recall_1: 0.9414 - val_specificity: 0.9137
# Epoch 8/200
# 72/75 [===========================>..] - ETA: 6s - loss: 0.2470 - accuracy: 0.9307 - dice_coef: 0.9420 - iou: 0.8920 - precision_1: 0.9323 - recall_1: 0.9541 - specificity: 0.9007

# %%
import matplotlib.pyplot as plt

# Visualization
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.title('Unet Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title('Unet Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train'], loc='upper left')

# Display the plot
plt.tight_layout()  # Adjusts subplot params for better layout
plt.show()

# Save the plot in a directory with high resolution
save_path = '/kaggle/working/plot.png'
plt.savefig(save_path, dpi=300)  # Save with 300 dpi for high resolution

print(f"Plot saved to {save_path}")

# %%
# Extract the training history
hist = history.history

# Calculate the average for each metric over all epochs
avg_accuracy = np.mean(hist['accuracy'])
avg_loss = np.mean(hist['loss'])
avg_dice_coef = np.mean(hist['dice_coef'])
avg_iou = np.mean(hist['iou'])
avg_precision = np.mean(hist['precision_2'])
avg_recall = np.mean(hist['recall_2'])
avg_specificity = np.mean(hist['specificity'])

# Print the results
print(f"Average Accuracy: {avg_accuracy:.4f}")
print(f"Average Loss: {avg_loss:.4f}")
print(f"Average Dice Coefficient: {avg_dice_coef:.4f}")
print(f"Average IoU: {avg_iou:.4f}")
print(f"Average Precision: {avg_precision:.4f}")
print(f"Average Recall: {avg_recall:.4f}")
print(f"Average Specificity: {avg_specificity:.4f}")

# %%
plt.figure(figsize=(12, 8))

# Plot training & validation accuracy
plt.subplot(2, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Unet Model Accuracy (AneRBC-II)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss
plt.subplot(2, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Unet Model Loss (AneRBC-II)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# Add more plots if you want to visualize other metrics like Dice Coefficient, IoU, etc.

plt.tight_layout()

# Save the figure in high definition
save_path = "/kaggle/working/Unet_Training_AneRBC2.png"  # Update with your desired path and filename
plt.savefig(save_path, dpi=300)  # 300 dpi is a good resolution for HD

plt.show()

# %%
# Plot training & validation IoU
plt.subplot(2, 3, 4)
plt.plot(history.history['iou'])
plt.plot(history.history['val_iou'])
plt.title('Unet IoU (AneRBC-II)')
plt.ylabel('IoU')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()

# Save the figure in high definition
save_path = "/kaggle/working/iou_AneRBC2.png"  
plt.savefig(save_path, dpi=300)  

plt.show()

# %%
# Plot training & validation Dice Coefficient
plt.subplot(2, 3, 3)
plt.plot(history.history['dice_coef'])
plt.plot(history.history['val_dice_coef'])
plt.title('Unet Dice Coefficient (AneRBC-II)')
plt.ylabel('Dice Coefficient')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.tight_layout()

# Save the figure in high definition
save_path = "/kaggle/working/dc_AmeRBC2.png"  
plt.savefig(save_path, dpi=300)  

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('/kaggle/input/linknet-results/training_link_net.csv')  # Replace 'path_to_your_csv_file.csv' with the path to your CSV file

# Create a dictionary to simulate the 'history.history' structure
history = {
    'accuracy': df['accuracy'].tolist(),
    'val_accuracy': df['val_accuracy'].tolist(),
    'loss': df['loss'].tolist(),
    'val_loss': df['val_loss'].tolist(),
    'iou': df['iou'].tolist(),
    ' val_iou': df[' val_iou'].tolist(),
    'dice_coef': df['dice_coef'].tolist(),
    'val_dice_coef': df['val_dice_coef'].tolist()
}

plt.figure(figsize=(12, 8))

# Plot training & validation accuracy
plt.subplot(2, 2, 1)
plt.plot(history['accuracy'])
plt.plot(history['loss'])
plt.title('LinkNet (AneRBC-I)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Traininig Accuracy', 'Training Loss'], loc='center right')

# Plot training & validation loss
plt.subplot(2, 2, 2)
plt.plot(history['val_accuracy'])
plt.plot(history['val_loss'])
plt.title('LinkNet (AneRBC-I)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Validation Accuracy', 'Validation Loss'], loc='center right')

plt.tight_layout()
save_path = "/kaggle/working/LinkNet_Training_AneRBC1.png"
plt.savefig(save_path, dpi=300)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a pandas DataFrame
df = pd.read_csv('/kaggle/input/linknet-results/training_link_net.csv')  # Replace with the path to your CSV file

# Convert the DataFrame columns to lists for plotting
accuracy = df['accuracy'].tolist()
val_accuracy = df['val_accuracy'].tolist()
loss = df['loss'].tolist()
val_loss = df['val_loss'].tolist()
iou = df['iou'].tolist()
val_iou = df[' val_iou'].tolist()
dice_coef = df['dice_coef'].tolist()
val_dice_coef = df['val_dice_coef'].tolist()

# %%
# 1) Training accuracy vs training loss
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(accuracy, label='Training Accuracy')
plt.plot(loss, label='Training Loss')
plt.title('LinkNet (AneRBC-I)')
plt.xlabel('Epoch')
plt.legend(loc='center right')
# save_path = "/kaggle/working/Training_Accuracy_vs_Loss_AneRBC1.png"
plt.savefig(save_path, dpi=300)
plt.show()

# 2) Validation accuracy vs Validation loss
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 2)
plt.plot(val_accuracy, label='Validation Accuracy')
plt.plot(val_loss, label='Validation Loss')
plt.title('LinkNet (AneRBC-I)')
plt.xlabel('Epoch')
plt.legend(loc='center right')
save_path = "/kaggle/working/Validation_Accuracy_vs_Loss_AneRBC1.png"
plt.savefig(save_path, dpi=300)
plt.show()

# %%
# 2) Validation accuracy vs Validation loss
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 2)
plt.plot(val_accuracy, label='Validation Accuracy')
plt.plot(val_loss, label='Validation Loss')
plt.title('LinkNet (AneRBC-I)')
plt.xlabel('Epoch')
plt.legend(loc='center right')
save_path = "/kaggle/working/Validation_Accuracy_vs_Loss_AneRBC1.png"
plt.savefig(save_path, dpi=300)
plt.show()

# %%
# 3) Training & validation IoU
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
plt.plot(iou, label='Training IoU')
plt.plot(val_iou, label='Validation IoU')
plt.title('LinkNet IoU (AneRBC-I)')
plt.xlabel('Epoch')
plt.legend(loc='center right')
save_path = "/kaggle/working/Training_Validation_IoU_AneRBC1.png"
plt.savefig(save_path, dpi=300)
plt.show()

# %%
# 4) Training & validation Dice Coefficient
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 2)
plt.plot(dice_coef, label='Training Dice Coefficient')
plt.plot(val_dice_coef, label='Validation Dice Coefficient')
plt.title('LinkNet Dice Coefficient (AneRBC-I)')
plt.xlabel('Epoch')
plt.legend(loc='center right')
save_path = "/kaggle/working/Training_Validation_DiceCoefficient_AneRBC1.png"
plt.savefig(save_path, dpi=300)
plt.show()
